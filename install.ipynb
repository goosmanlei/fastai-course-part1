# %%
# !brew install pyenv

# !pyenv install 3.10.19
# !echo 'eval "$(pyenv init -)"' >> ~/.bashrc
# !source ~/.bashrc

# !cd your_project
# !pyenv local 3.10.19
# !python --version   # 必须显示 3.10.19

# !python -m venv ~/venvs/fastbook
# !echo 'source .venvs/fastbook/bin/activate' >> ~/.bashrc
# !source ~/.bashrc
# !python --version


# !pip install -U \
  pip setuptools wheel \
  jupyter jupyterlab ipykernel \
  notebook nbclassic \
  jupyter_contrib_nbextensions \
  fastprogress===1.0.3 \
  fastai fastbook fastkaggle \
  torch torchvision torchaudio \
  numpy pandas scipy scikit-learn \
  matplotlib seaborn plotly \
  pillow opencv-python \
  tqdm rich requests \
  ipywidgets widgetsnbextension \
  kaggle

# 安装 ipykernel 到虚拟环境中
# !python -m ipykernel install --user \
  --name fastbook \
  --display-name "python-venv-fastbook"

# 检查fastai/torch是否安装成功
python - << 'EOF'
import torch, fastai
print("torch:", torch.__version__)
print("cuda:", torch.cuda.is_available())
print("fastai:", fastai.__version__)
EOF
